# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# ## **Load data**

# %% [markdown]
# ## **Environment setup (dependency fix)**

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# !pip install -q tf_keras "tensorflow_model_optimization==0.8.1"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 6.0 MB/s eta 0:00:00

# %%
from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import shutil, os
from tensorflow.keras import layers, models
from tensorflow.keras import Model
from tensorflow.keras.applications import EfficientNetV2B2
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import urllib.request
import zipfile
import random
from tensorflow.keras import Input
import time
import pandas as pd
import tensorflow_model_optimization as tfmot
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import Callback

#import seaborn as sns
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import f1_score
# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Download CK+**

# %%
# # Download CK+ dataset to Google Drive
# url = "https://storage.googleapis.com/kaggle-data-sets/65125/128470/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230713%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230713T184454Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# extract_dir = "/content/drive/MyDrive/CKplus_48.28"

# zip_path, _ = urllib.request.urlretrieve(url)
# with zipfile.ZipFile(zip_path, "r") as f:
#     f.extractall(extract_dir)

# %%
extract_dir = "/content/drive/MyDrive/CKplus_48.28"
# !unzip -q archive\(5\).zip -d /content/drive/MyDrive/CKplus_48.28

# %% [markdown]
# ### **Split data into train, test and validation**

# %%
base_dir = '/content/drive/MyDrive/generated'
os.mkdir(base_dir)
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_2228/3702282617.py in <cell line: 0>()
#       1 base_dir = '/content/drive/MyDrive/generated'
# ----> 2 os.mkdir(base_dir)
#       3 train_dir = os.path.join(base_dir, 'train')
#       4 os.mkdir(train_dir)
#       5 validation_dir = os.path.join(base_dir, 'validation')
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/generated'

# %%
train_surprise_dir = os.path.join(train_dir, 'surprise')
os.mkdir(train_surprise_dir)
train_contempt_dir = os.path.join(train_dir, 'contempt')
os.mkdir(train_contempt_dir)
train_disgust_dir = os.path.join(train_dir, 'disgust')
os.mkdir(train_disgust_dir)
train_fear_dir = os.path.join(train_dir, 'fear')
os.mkdir(train_fear_dir)
train_anger_dir = os.path.join(train_dir, 'anger')
os.mkdir(train_anger_dir)
train_sadness_dir = os.path.join(train_dir, 'sadness')
os.mkdir(train_sadness_dir)
train_happy_dir = os.path.join(train_dir, 'happy')
os.mkdir(train_happy_dir)

validation_surprise_dir = os.path.join(validation_dir, 'surprise')
os.mkdir(validation_surprise_dir)
validation_contempt_dir = os.path.join(validation_dir, 'contempt')
os.mkdir(validation_contempt_dir)
validation_disgust_dir = os.path.join(validation_dir, 'disgust')
os.mkdir(validation_disgust_dir)
validation_fear_dir = os.path.join(validation_dir, 'fear')
os.mkdir(validation_fear_dir)
validation_anger_dir = os.path.join(validation_dir, 'anger')
os.mkdir(validation_anger_dir)
validation_sadness_dir = os.path.join(validation_dir, 'sadness')
os.mkdir(validation_sadness_dir)
validation_happy_dir = os.path.join(validation_dir, 'happy')
os.mkdir(validation_happy_dir)

test_surprise_dir = os.path.join(test_dir, 'surprise')
os.mkdir(test_surprise_dir)
test_contempt_dir = os.path.join(test_dir, 'contempt')
os.mkdir(test_contempt_dir)
test_disgust_dir = os.path.join(test_dir, 'disgust')
os.mkdir(test_disgust_dir)
test_fear_dir = os.path.join(test_dir, 'fear')
os.mkdir(test_fear_dir)
test_anger_dir = os.path.join(test_dir, 'anger')
os.mkdir(test_anger_dir)
test_sadness_dir = os.path.join(test_dir, 'sadness')
os.mkdir(test_sadness_dir)
test_happy_dir = os.path.join(test_dir, 'happy')
os.mkdir(test_happy_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_2228/209943317.py in <cell line: 0>()
#       1 train_surprise_dir = os.path.join(train_dir, 'surprise')
# ----> 2 os.mkdir(train_surprise_dir)
#       3 train_contempt_dir = os.path.join(train_dir, 'contempt')
#       4 os.mkdir(train_contempt_dir)
#       5 train_disgust_dir = os.path.join(train_dir, 'disgust')
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/generated/train/surprise'

# %%
original_surprise_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/surprise'
original_contempt_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/contempt'
original_disgust_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/disgust'
original_fear_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/fear'
original_anger_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/anger'
original_sadness_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/sadness'
original_happy_dir = r'/content/drive/MyDrive/CKplus_48.28/ck/CK+48/happy'

# %%
def get_file_list(input_dir):
    return [file for file in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, file))]

def get_random_files(file_list, N):
    return random.sample(file_list, N)

def move_files(random_files, input_dir, output_dir):
    for file in random_files:
        shutil.move(os.path.join(input_dir, file), output_dir)

def main(input_dir, output_dir, N):
    file_list = get_file_list(input_dir)
    random_files = get_random_files(file_list, N)
    move_files(random_files, input_dir, output_dir)
def remain(input_dir, output_dir):
  file_list = get_file_list(input_dir)
  for file in file_list:
    shutil.move(os.path.join(input_dir, file), output_dir)

# %%
transfer_list = [(original_surprise_dir,train_surprise_dir,validation_surprise_dir,test_surprise_dir),
                            (original_sadness_dir,train_sadness_dir,validation_sadness_dir,test_sadness_dir),
                            (original_anger_dir,train_anger_dir,validation_anger_dir,test_anger_dir),
                            (original_contempt_dir,train_contempt_dir,validation_contempt_dir,test_contempt_dir),
                            (original_happy_dir,train_happy_dir,validation_happy_dir,test_happy_dir),
                            (original_disgust_dir,train_disgust_dir,validation_disgust_dir,test_disgust_dir),
                            (original_fear_dir,train_fear_dir,validation_fear_dir,test_fear_dir)]
for src, dst1, dst2, dst3 in transfer_list:
    main(src , dst1 , int(0.7 * len([name for name in os.listdir(src) if os.path.isfile(os.path.join(src, name))])))
    print(src.split('/')[-1], 'train Done!')
    main(src , dst2 , int(0.5 * len([name for name in os.listdir(src) if os.path.isfile(os.path.join(src, name))])))
    print(src.split('/')[-1], 'validation Done!')
    remain(src,dst3)
    print(src.split('/')[-1], 'test Done!')
    print('---------------')
# Out:
# surprise train Done!
# surprise validation Done!
# surprise test Done!
# ---------------
# sadness train Done!
# sadness validation Done!
# sadness test Done!
# ---------------
# anger train Done!
# anger validation Done!
# anger test Done!
# ---------------
# contempt train Done!
# contempt validation Done!
# contempt test Done!
# ---------------
# happy train Done!
# happy validation Done!
# happy test Done!
# ---------------
# disgust train Done!
# disgust validation Done!
# disgust test Done!
# ---------------
# fear train Done!
# fear validation Done!
# fear test Done!
# ---------------

# %%
train_surprise_dir = r'/content/drive/MyDrive/generated2/train/surprise'
train_contempt_dir = r'/content/drive/MyDrive/generated2/train/contempt'
train_disgust_dir = r'/content/drive/MyDrive/generated2/train/disgust'
train_fear_dir = r'/content/drive/MyDrive/generated2/train/fear'
train_anger_dir = r'/content/drive/MyDrive/generated2/train/anger'
train_sadness_dir = r'/content/drive/MyDrive/generated2/train/sadness'
train_happy_dir = r'/content/drive/MyDrive/generated2/train/happy'

# %%
validation_surprise_dir = r'/content/drive/MyDrive/generated2/validation/surprise'
validation_contempt_dir = r'/content/drive/MyDrive/generated2/validation/contempt'
validation_disgust_dir = r'/content/drive/MyDrive/generated2/validation/disgust'
validation_fear_dir = r'/content/drive/MyDrive/generated2/validation/fear'
validation_anger_dir = r'/content/drive/MyDrive/generated2/validation/anger'
validation_sadness_dir = r'/content/drive/MyDrive/generated2/validation/sadness'
validation_happy_dir = r'/content/drive/MyDrive/generated2/validation/happy'

# %%
test_surprise_dir = r'/content/drive/MyDrive/generated2/test/surprise'
test_contempt_dir = r'/content/drive/MyDrive/generated2/test/contempt'
test_disgust_dir = r'/content/drive/MyDrive/generated2/test/disgust'
test_fear_dir = r'/content/drive/MyDrive/generated2/test/fear'
test_anger_dir = r'/content/drive/MyDrive/generated2/test/anger'
test_sadness_dir = r'/content/drive/MyDrive/generated2/test/sadness'
test_happy_dir = r'/content/drive/MyDrive/generated2/test/happy'

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# ## **Solving imbalanced dataset problem**

# %%
t_surprise = len([name for name in os.listdir(train_surprise_dir) if os.path.isfile(os.path.join(train_surprise_dir, name))])
t_sadness = len([name for name in os.listdir(train_sadness_dir) if os.path.isfile(os.path.join(train_sadness_dir, name))])
t_happy = len([name for name in os.listdir(train_happy_dir) if os.path.isfile(os.path.join(train_happy_dir, name))])
t_fear = len([name for name in os.listdir(train_fear_dir) if os.path.isfile(os.path.join(train_fear_dir, name))])
t_disgust = len([name for name in os.listdir(train_disgust_dir) if os.path.isfile(os.path.join(train_disgust_dir, name))])
t_contempt = len([name for name in os.listdir(train_contempt_dir) if os.path.isfile(os.path.join(train_contempt_dir, name))])
t_anger = len([name for name in os.listdir(train_anger_dir) if os.path.isfile(os.path.join(train_anger_dir, name))])
label_list = [t_surprise, t_sadness, t_happy, t_fear, t_disgust, t_contempt, t_anger]
total = 0
max = 0
for each in label_list:
  total+=each
  if each > max:
    max = each

w_surprise = float(max/t_surprise)
w_sadness = float(max/t_sadness)
w_happy = float(max/t_happy)
w_fear = float(max/t_fear)
w_disgust = float(max/t_disgust)
w_contempt = float(max/t_contempt)
w_anger = float(max/t_anger)

# %%
class_weight = {0: w_surprise,
                1: w_sadness,
                2: w_happy,
                3: w_fear,
                4: w_disgust,
                5: w_contempt,
                6: w_anger}

# %% [markdown]
# ## **Augmentation, Normalization and Resizing with ImageDataGenerator**

# %%
train_datagen = ImageDataGenerator(preprocessing_function=lambda x: (x / 127.5) - 1.0,
                                   rotation_range = 40,
                                   width_shift_range = 0.25,
                                   height_shift_range = 0.25,
                                   shear_range = 0.25,
                                   zoom_range = 0.25,
                                   horizontal_flip = True,
                                   fill_mode='nearest')
test_datagen = ImageDataGenerator(preprocessing_function=lambda x: (x / 127.5) - 1.0)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(260, 260),
        batch_size=16,
        class_mode='categorical')
validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(260, 260),
        batch_size=16,
        class_mode='categorical')
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(260, 260),
        class_mode='categorical')
# Out:
# Found 682 images belonging to 7 classes.
# Found 147 images belonging to 7 classes.
# Found 152 images belonging to 7 classes.

# %% [markdown]
# ## **Visualization for images after augmentation, normalization and resizing**

# %%
for _ in range(2):
    img, label = train_generator.next()
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.show()
    print(img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9607843..1.0].
# (16, 260, 260, 3)
# [[[[-0.8039216  -0.8039216  -0.8039216 ]
#    [-0.8039216  -0.8039216  -0.8039216 ]
#    [-0.8039216  -0.8039216  -0.8039216 ]
#    ...
#    [-0.7176471  -0.7176471  -0.7176471 ]
#    [-0.7176471  -0.7176471  -0.7176471 ]
#    [-0.7176471  -0.7176471  -0.7176471 ]]
#
#   [[-0.8039216  -0.8039216  -0.8039216 ]
#    [-0.8039216  -0.8039216  -0.8039216 ]
#    [-0.8039216  -0.8039216  -0.8039216 ]
#    ...
#    [-0.7176471  -0.7176471  -0.7176471 ]
#    [-0.7176471  -0.7176471  -0.7176471 ]
#    [-0.7176471  -0.7176471  -0.7176471 ]]
#
#   [[-0.8039216  -0.8039216  -0.8039216 ]
#    [-0.8039216  -0.8039216  -0.8039216 ]
#    [-0.8039216  -0.8039216  -0.8039216 ]
#    ...
#    [-0.7176471  -0.7176471  -0.7176471 ]
#    [-0.7176471  -0.7176471  -0.7176471 ]
#    [-0.7176471  -0.7176471  -0.7176471 ]]
#
#   ...
#
#   [[-0.4424445  -0.4424445  -0.4424445 ]
#    [-0.5529412  -0.5529412  -0.5529412 ]
#    [-0.5529412  -0.5529412  -0.5529412 ]
#    ...
#    [ 0.21568632  0.21568632  0.21568632]
#    [ 0.21568632  0.21568632  0.21568632]
#    [ 0.21568632  0.21568632  0.21568632]]
#
#   [[-0.48944664 -0.48944664 -0.48944664]
#    [-0.5529412  -0.5529412  -0.5529412 ]
#    [-0.5529412  -0.5529412  -0.5529412 ]
#    ...
#    [ 0.21568632  0.21568632  0.21568632]
#    [ 0.21568632  0.21568632  0.21568632]
#    [ 0.21568632  0.21568632  0.21568632]]
#
#   [[-0.53644884 -0.53644884 -0.53644884]
#    [-0.5529412  -0.5529412  -0.5529412 ]
#    [-0.5529412  -0.5529412  -0.5529412 ]
#    ...
#    [ 0.21568632  0.21568632  0.21568632]
#    [ 0.21568632  0.21568632  0.21568632]
#    [ 0.21568632  0.21568632  0.21568632]]]
#
#
# %%
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (16, 260, 260, 3)
# labels batch shape: (16, 7)

# %% [markdown]
# # **Fine-tuning**

# %% [markdown]
# ## **Load Efficientnetv2-b2 with initializing pre-trained weights and changing last layer**

# %%
pre_trained_model = EfficientNetV2B2(include_top = True,
                                include_preprocessing=False,
                                pooling=None,
                                weights = 'imagenet',
                                input_tensor=Input(shape=(260, 260, 3)))
last_layer = pre_trained_model.get_layer('top_dropout')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
x = layers.Dense(7, activation='softmax')(last_output)
model = Model(pre_trained_model.input, x)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2.h5
# 41480120/41480120 [==============================] - 0s 0us/step
# last layer output shape:  (None, 1408)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 260, 260, 3)]        0         []
#
#  stem_conv (Conv2D)          (None, 130, 130, 32)         864       ['input_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 130, 130, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 130, 130, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 130, 130, 16)         4608      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 130, 130, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 130, 130, 16)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1b_project_conv (Conv  (None, 130, 130, 16)         2304      ['block1a_project_activation[0
#  2D)                                                                ][0]']
#
#  block1b_project_bn (BatchN  (None, 130, 130, 16)         64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 130, 130, 16)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 130, 130, 16)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 130, 130, 16)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_activation[0
#                                                                     ][0]']
#
#  block2a_expand_conv (Conv2  (None, 65, 65, 64)           9216      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 65, 65, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 65, 65, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 65, 65, 32)           2048      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 65, 65, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 65, 65, 128)          36864     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 65, 65, 128)          512       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 65, 65, 128)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 65, 65, 32)           4096      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 65, 65, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 65, 65, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 65, 65, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 65, 65, 128)          36864     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 65, 65, 128)          512       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 65, 65, 128)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 65, 65, 32)           4096      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 65, 65, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 65, 65, 32)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 65, 65, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 33, 33, 128)          36864     ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 33, 33, 128)          512       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 33, 33, 128)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 33, 33, 56)           7168      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 33, 33, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 33, 33, 224)          112896    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 33, 33, 224)          896       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 33, 33, 224)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 33, 33, 56)           12544     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 33, 33, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 33, 33, 56)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 33, 33, 56)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 33, 33, 224)          112896    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 33, 33, 224)          896       ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 33, 33, 224)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 33, 33, 56)           12544     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 33, 33, 56)           224       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 33, 33, 56)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 33, 33, 56)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 33, 33, 224)          12544     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 33, 33, 224)          896       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 33, 33, 224)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 17, 17, 224)          2016      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 17, 17, 224)          896       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 17, 17, 224)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 224)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 224)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             3150      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 224)            3360      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 17, 17, 224)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 17, 17, 104)          23296     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 17, 17, 104)          416       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 17, 17, 416)          43264     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 17, 17, 416)          1664      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 17, 17, 416)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 17, 17, 416)          3744      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 17, 17, 416)          1664      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 17, 17, 416)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 416)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 416)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 26)             10842     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 416)            11232     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 17, 17, 416)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 17, 17, 104)          43264     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 17, 17, 104)          416       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 17, 17, 104)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 17, 17, 104)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 17, 17, 416)          43264     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 17, 17, 416)          1664      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 17, 17, 416)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 17, 17, 416)          3744      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 17, 17, 416)          1664      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 17, 17, 416)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 416)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 416)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 26)             10842     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 416)            11232     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 17, 17, 416)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 17, 17, 104)          43264     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 17, 17, 104)          416       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 17, 17, 104)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 17, 17, 104)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 17, 17, 416)          43264     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 17, 17, 416)          1664      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 17, 17, 416)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 17, 17, 416)          3744      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 17, 17, 416)          1664      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 17, 17, 416)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 416)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 416)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 26)             10842     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 416)            11232     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 17, 17, 416)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 17, 17, 104)          43264     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 17, 17, 104)          416       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 17, 17, 104)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 17, 17, 104)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 17, 17, 624)          64896     ['block4d_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 17, 17, 624)          2496      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 17, 17, 624)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 17, 17, 624)          5616      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 17, 17, 624)          2496      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 17, 17, 624)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 624)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 624)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 26)             16250     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 624)            16848     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 17, 17, 624)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 17, 17, 120)          74880     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 17, 17, 120)          480       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 17, 17, 720)          86400     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 17, 17, 720)          2880      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 17, 17, 720)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 17, 17, 720)          6480      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 17, 17, 720)          2880      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 17, 17, 720)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 720)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 720)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 30)             21630     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 720)            22320     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 17, 17, 720)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 17, 17, 120)          86400     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 17, 17, 120)          480       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 17, 17, 120)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 17, 17, 120)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 17, 17, 720)          86400     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 17, 17, 720)          2880      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 17, 17, 720)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 17, 17, 720)          6480      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 17, 17, 720)          2880      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 17, 17, 720)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 720)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 720)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 30)             21630     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 720)            22320     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 17, 17, 720)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 17, 17, 120)          86400     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 17, 17, 120)          480       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 17, 17, 120)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 17, 17, 120)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 17, 17, 720)          86400     ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 17, 17, 720)          2880      ['block5d_expand_conv[0][0]']
#  rmalization)
#
#  block5d_expand_activation   (None, 17, 17, 720)          0         ['block5d_expand_bn[0][0]']
#  (Activation)
#
#  block5d_dwconv2 (Depthwise  (None, 17, 17, 720)          6480      ['block5d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5d_bn (BatchNormaliza  (None, 17, 17, 720)          2880      ['block5d_dwconv2[0][0]']
#  tion)
#
#  block5d_activation (Activa  (None, 17, 17, 720)          0         ['block5d_bn[0][0]']
#  tion)
#
#  block5d_se_squeeze (Global  (None, 720)                  0         ['block5d_activation[0][0]']
#  AveragePooling2D)
#
#  block5d_se_reshape (Reshap  (None, 1, 1, 720)            0         ['block5d_se_squeeze[0][0]']
#  e)
#
#  block5d_se_reduce (Conv2D)  (None, 1, 1, 30)             21630     ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)  (None, 1, 1, 720)            22320     ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multipl  (None, 17, 17, 720)          0         ['block5d_activation[0][0]',
#  y)                                                                  'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv  (None, 17, 17, 120)          86400     ['block5d_se_excite[0][0]']
#  2D)
#
#  block5d_project_bn (BatchN  (None, 17, 17, 120)          480       ['block5d_project_conv[0][0]']
#  ormalization)
#
#  block5d_drop (Dropout)      (None, 17, 17, 120)          0         ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)           (None, 17, 17, 120)          0         ['block5d_drop[0][0]',
#                                                                      'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2  (None, 17, 17, 720)          86400     ['block5d_add[0][0]']
#  D)
#
#  block5e_expand_bn (BatchNo  (None, 17, 17, 720)          2880      ['block5e_expand_conv[0][0]']
#  rmalization)
#
#  block5e_expand_activation   (None, 17, 17, 720)          0         ['block5e_expand_bn[0][0]']
#  (Activation)
# ...
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 9, 9, 1248)           0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 9, 9, 208)            259584    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 9, 9, 208)            832       ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (Dropout)      (None, 9, 9, 208)            0         ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)           (None, 9, 9, 208)            0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 9, 9, 1248)           259584    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 9, 9, 1248)           4992      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 9, 9, 1248)           0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv2 (Depthwise  (None, 9, 9, 1248)           11232     ['block6h_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6h_bn (BatchNormaliza  (None, 9, 9, 1248)           4992      ['block6h_dwconv2[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 9, 9, 1248)           0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1248)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 9, 9, 1248)           0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 9, 9, 208)            259584    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 9, 9, 208)            832       ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (Dropout)      (None, 9, 9, 208)            0         ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)           (None, 9, 9, 208)            0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  block6i_expand_conv (Conv2  (None, 9, 9, 1248)           259584    ['block6h_add[0][0]']
#  D)
#
#  block6i_expand_bn (BatchNo  (None, 9, 9, 1248)           4992      ['block6i_expand_conv[0][0]']
#  rmalization)
#
#  block6i_expand_activation   (None, 9, 9, 1248)           0         ['block6i_expand_bn[0][0]']
#  (Activation)
#
#  block6i_dwconv2 (Depthwise  (None, 9, 9, 1248)           11232     ['block6i_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6i_bn (BatchNormaliza  (None, 9, 9, 1248)           4992      ['block6i_dwconv2[0][0]']
#  tion)
#
#  block6i_activation (Activa  (None, 9, 9, 1248)           0         ['block6i_bn[0][0]']
#  tion)
#
#  block6i_se_squeeze (Global  (None, 1248)                 0         ['block6i_activation[0][0]']
#  AveragePooling2D)
#
#  block6i_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6i_se_squeeze[0][0]']
#  e)
#
#  block6i_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multipl  (None, 9, 9, 1248)           0         ['block6i_activation[0][0]',
#  y)                                                                  'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv  (None, 9, 9, 208)            259584    ['block6i_se_excite[0][0]']
#  2D)
#
#  block6i_project_bn (BatchN  (None, 9, 9, 208)            832       ['block6i_project_conv[0][0]']
#  ormalization)
#
#  block6i_drop (Dropout)      (None, 9, 9, 208)            0         ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)           (None, 9, 9, 208)            0         ['block6i_drop[0][0]',
#                                                                      'block6h_add[0][0]']
#
#  block6j_expand_conv (Conv2  (None, 9, 9, 1248)           259584    ['block6i_add[0][0]']
#  D)
#
#  block6j_expand_bn (BatchNo  (None, 9, 9, 1248)           4992      ['block6j_expand_conv[0][0]']
#  rmalization)
#
#  block6j_expand_activation   (None, 9, 9, 1248)           0         ['block6j_expand_bn[0][0]']
#  (Activation)
#
#  block6j_dwconv2 (Depthwise  (None, 9, 9, 1248)           11232     ['block6j_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6j_bn (BatchNormaliza  (None, 9, 9, 1248)           4992      ['block6j_dwconv2[0][0]']
#  tion)
#
#  block6j_activation (Activa  (None, 9, 9, 1248)           0         ['block6j_bn[0][0]']
#  tion)
#
#  block6j_se_squeeze (Global  (None, 1248)                 0         ['block6j_activation[0][0]']
#  AveragePooling2D)
#
#  block6j_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6j_se_squeeze[0][0]']
#  e)
#
#  block6j_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6j_se_reshape[0][0]']
#
#  block6j_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6j_se_reduce[0][0]']
#
#  block6j_se_excite (Multipl  (None, 9, 9, 1248)           0         ['block6j_activation[0][0]',
#  y)                                                                  'block6j_se_expand[0][0]']
#
#  block6j_project_conv (Conv  (None, 9, 9, 208)            259584    ['block6j_se_excite[0][0]']
#  2D)
#
#  block6j_project_bn (BatchN  (None, 9, 9, 208)            832       ['block6j_project_conv[0][0]']
#  ormalization)
#
#  block6j_drop (Dropout)      (None, 9, 9, 208)            0         ['block6j_project_bn[0][0]']
#
#  block6j_add (Add)           (None, 9, 9, 208)            0         ['block6j_drop[0][0]',
#                                                                      'block6i_add[0][0]']
#
#  top_conv (Conv2D)           (None, 9, 9, 1408)           292864    ['block6j_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 9, 9, 1408)           5632      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 9, 9, 1408)           0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 1408)                 0         ['top_activation[0][0]']
#  ling2D)
#
#  top_dropout (Dropout)       (None, 1408)                 0         ['avg_pool[0][0]']
#
#  dense (Dense)               (None, 7)                    9863      ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 8779237 (33.49 MB)
# Trainable params: 8696949 (33.18 MB)
# Non-trainable params: 82288 (321.44 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',    #'keras.optimizers.Adam(learning_rate=0.0001)',
              metrics=['accuracy'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy')>0.98 and logs.get('accuracy')>0.98):
      print("\nReached 98% val_accuracy so cancelling training!")
      self.model.stop_training = True
    else:
      self.model.stop_training = False
      print(" .It's Not good yet!")

# %%
#instantiate myCallback
callbacks_instantiate = myCallback()

# %% [markdown]
# # **Training process**

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=42,
      epochs=60,
      validation_data=validation_generator,
      validation_steps=9,
      class_weight=class_weight,
      callbacks=[callbacks_instantiate])
# Out:
# Epoch 1/60
# 42/42 [==============================] - ETA: 0s - loss: 3.3963 - accuracy: 0.3348 .It's Not good yet!
# 42/42 [==============================] - 80s 466ms/step - loss: 3.3963 - accuracy: 0.3348 - val_loss: 1.2596 - val_accuracy: 0.5556
# Epoch 2/60
# 42/42 [==============================] - ETA: 0s - loss: 2.0316 - accuracy: 0.6411 .It's Not good yet!
# 42/42 [==============================] - 18s 421ms/step - loss: 2.0316 - accuracy: 0.6411 - val_loss: 0.5352 - val_accuracy: 0.8056
# Epoch 3/60
# 42/42 [==============================] - ETA: 0s - loss: 1.5051 - accuracy: 0.7440 .It's Not good yet!
# 42/42 [==============================] - 19s 455ms/step - loss: 1.5051 - accuracy: 0.7440 - val_loss: 0.3843 - val_accuracy: 0.8750
# Epoch 4/60
# 42/42 [==============================] - ETA: 0s - loss: 1.1322 - accuracy: 0.7883 .It's Not good yet!
# 42/42 [==============================] - 19s 443ms/step - loss: 1.1322 - accuracy: 0.7883 - val_loss: 0.1696 - val_accuracy: 0.9583
# Epoch 5/60
# 42/42 [==============================] - ETA: 0s - loss: 0.8179 - accuracy: 0.8604 .It's Not good yet!
# 42/42 [==============================] - 18s 423ms/step - loss: 0.8179 - accuracy: 0.8604 - val_loss: 0.2226 - val_accuracy: 0.9236
# Epoch 6/60
# 42/42 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.8664 .It's Not good yet!
# 42/42 [==============================] - 18s 425ms/step - loss: 0.7473 - accuracy: 0.8664 - val_loss: 0.1704 - val_accuracy: 0.9236
# Epoch 31/60
# 42/42 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.9429 .It's Not good yet!
# 42/42 [==============================] - 18s 427ms/step - loss: 0.3236 - accuracy: 0.9429 - val_loss: 0.0381 - val_accuracy: 0.9861
# Epoch 32/60
# 42/42 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9489 .It's Not good yet!
# 42/42 [==============================] - 18s 421ms/step - loss: 0.2383 - accuracy: 0.9489 - val_loss: 0.2172 - val_accuracy: 0.9514
# Epoch 33/60
# 42/42 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9595 .It's Not good yet!
# 42/42 [==============================] - 20s 466ms/step - loss: 0.2356 - accuracy: 0.9595 - val_loss: 0.1011 - val_accuracy: 0.9653
# Epoch 34/60
# 42/42 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9760 .It's Not good yet!
# 42/42 [==============================] - 18s 430ms/step - loss: 0.1662 - accuracy: 0.9760 - val_loss: 0.0748 - val_accuracy: 0.9792
# Epoch 35/60
# 42/42 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9715 .It's Not good yet!
# 42/42 [==============================] - 18s 435ms/step - loss: 0.1598 - accuracy: 0.9715 - val_loss: 0.0246 - val_accuracy: 0.9931
# Epoch 36/60
# 42/42 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.9700 .It's Not good yet!
# 42/42 [==============================] - 18s 427ms/step - loss: 0.2481 - accuracy: 0.9700 - val_loss: 0.0788 - val_accuracy: 0.9792
# Epoch 37/60
# 42/42 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9489 .It's Not good yet!
# 42/42 [==============================] - 18s 421ms/step - loss: 0.2395 - accuracy: 0.9489 - val_loss: 0.0841 - val_accuracy: 0.9792
# Epoch 38/60
# 42/42 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9474 .It's Not good yet!
# 42/42 [==============================] - 18s 430ms/step - loss: 0.3083 - accuracy: 0.9474 - val_loss: 0.0370 - val_accuracy: 0.9792
# Epoch 39/60
# 42/42 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9805
# Reached 98% val_accuracy so cancelling training!
# 42/42 [==============================] - 19s 442ms/step - loss: 0.1456 - accuracy: 0.9805 - val_loss: 0.0639 - val_accuracy: 0.9861

# %% [markdown]
# # **Evaluation**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.evaluate(test_generator, verbose=2)
# Out:
# 5/5 - 2s - loss: 0.0619 - accuracy: 0.9737 - 2s/epoch - 480ms/step
# [0.06185511499643326, 0.9736841917037964]

# %%
model.save('/content/drive/MyDrive/ENV2B2CK+.h5')
# Out:
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # **Quantizaion**

# %% [markdown]
# ## **Quantizaion-aware training (QAT) - Quantization int8 (integer 8) with fine-tuning**

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/ENV2B2CK+.h5')

# %%
def apply_quantization_layers(layer):
    if 'se_excite' in layer.name:
        return layer
    return tfmot.quantization.keras.quantize_annotate_layer(layer)

annotated_model = tf.keras.models.clone_model(
    model,
    clone_function=apply_quantization_layers,
)

quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model)
quant_aware_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 260, 260, 3)]        0         []
#
#  quantize_layer (QuantizeLa  (None, 260, 260, 3)          3         ['input_1[0][0]']
#  yer)
#
#  quant_stem_conv (QuantizeW  (None, 130, 130, 32)         929       ['quantize_layer[0][0]']
#  rapperV2)
#
#  quant_stem_bn (QuantizeWra  (None, 130, 130, 32)         131       ['quant_stem_conv[0][0]']
#  pperV2)
#
#  quant_stem_activation (Qua  (None, 130, 130, 32)         3         ['quant_stem_bn[0][0]']
#  ntizeWrapperV2)
#
#  quant_block1a_project_conv  (None, 130, 130, 16)         4641      ['quant_stem_activation[0][0]'
#   (QuantizeWrapperV2)                                               ]
#
#  quant_block1a_project_bn (  (None, 130, 130, 16)         67        ['quant_block1a_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block1a_project_acti  (None, 130, 130, 16)         3         ['quant_block1a_project_bn[0][
#  vation (QuantizeWrapperV2)                                         0]']
#
#  quant_block1b_project_conv  (None, 130, 130, 16)         2337      ['quant_block1a_project_activa
#   (QuantizeWrapperV2)                                               tion[0][0]']
#
#  quant_block1b_project_bn (  (None, 130, 130, 16)         67        ['quant_block1b_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block1b_project_acti  (None, 130, 130, 16)         3         ['quant_block1b_project_bn[0][
#  vation (QuantizeWrapperV2)                                         0]']
#
#  quant_block1b_drop (Quanti  (None, 130, 130, 16)         1         ['quant_block1b_project_activa
#  zeWrapperV2)                                                       tion[0][0]']
#
#  quant_block1b_add (Quantiz  (None, 130, 130, 16)         3         ['quant_block1b_drop[0][0]',
#  eWrapperV2)                                                         'quant_block1a_project_activa
#                                                                     tion[0][0]']
#
#  quant_block2a_expand_conv   (None, 65, 65, 64)           9345      ['quant_block1b_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block2a_expand_bn (Q  (None, 65, 65, 64)           259       ['quant_block2a_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block2a_expand_activ  (None, 65, 65, 64)           3         ['quant_block2a_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block2a_project_conv  (None, 65, 65, 32)           2113      ['quant_block2a_expand_activat
#   (QuantizeWrapperV2)                                               ion[0][0]']
#
#  quant_block2a_project_bn (  (None, 65, 65, 32)           131       ['quant_block2a_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block2b_expand_conv   (None, 65, 65, 128)          37121     ['quant_block2a_project_bn[0][
#  (QuantizeWrapperV2)                                                0]']
#
#  quant_block2b_expand_bn (Q  (None, 65, 65, 128)          515       ['quant_block2b_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block2b_expand_activ  (None, 65, 65, 128)          3         ['quant_block2b_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block2b_project_conv  (None, 65, 65, 32)           4161      ['quant_block2b_expand_activat
#   (QuantizeWrapperV2)                                               ion[0][0]']
#
#  quant_block2b_project_bn (  (None, 65, 65, 32)           131       ['quant_block2b_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block2b_drop (Quanti  (None, 65, 65, 32)           1         ['quant_block2b_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block2b_add (Quantiz  (None, 65, 65, 32)           3         ['quant_block2b_drop[0][0]',
#  eWrapperV2)                                                         'quant_block2a_project_bn[0][
#                                                                     0]']
#
#  quant_block2c_expand_conv   (None, 65, 65, 128)          37121     ['quant_block2b_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block2c_expand_bn (Q  (None, 65, 65, 128)          515       ['quant_block2c_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block2c_expand_activ  (None, 65, 65, 128)          3         ['quant_block2c_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block2c_project_conv  (None, 65, 65, 32)           4161      ['quant_block2c_expand_activat
#   (QuantizeWrapperV2)                                               ion[0][0]']
#
#  quant_block2c_project_bn (  (None, 65, 65, 32)           131       ['quant_block2c_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block2c_drop (Quanti  (None, 65, 65, 32)           1         ['quant_block2c_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block2c_add (Quantiz  (None, 65, 65, 32)           3         ['quant_block2c_drop[0][0]',
#  eWrapperV2)                                                         'quant_block2b_add[0][0]']
#
#  quant_block3a_expand_conv   (None, 33, 33, 128)          37121     ['quant_block2c_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block3a_expand_bn (Q  (None, 33, 33, 128)          515       ['quant_block3a_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block3a_expand_activ  (None, 33, 33, 128)          3         ['quant_block3a_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block3a_project_conv  (None, 33, 33, 56)           7281      ['quant_block3a_expand_activat
#   (QuantizeWrapperV2)                                               ion[0][0]']
#
#  quant_block3a_project_bn (  (None, 33, 33, 56)           227       ['quant_block3a_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block3b_expand_conv   (None, 33, 33, 224)          113345    ['quant_block3a_project_bn[0][
#  (QuantizeWrapperV2)                                                0]']
#
#  quant_block3b_expand_bn (Q  (None, 33, 33, 224)          899       ['quant_block3b_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block3b_expand_activ  (None, 33, 33, 224)          3         ['quant_block3b_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block3b_project_conv  (None, 33, 33, 56)           12657     ['quant_block3b_expand_activat
#   (QuantizeWrapperV2)                                               ion[0][0]']
#
#  quant_block3b_project_bn (  (None, 33, 33, 56)           227       ['quant_block3b_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block3b_drop (Quanti  (None, 33, 33, 56)           1         ['quant_block3b_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block3b_add (Quantiz  (None, 33, 33, 56)           3         ['quant_block3b_drop[0][0]',
#  eWrapperV2)                                                         'quant_block3a_project_bn[0][
#                                                                     0]']
#
#  quant_block3c_expand_conv   (None, 33, 33, 224)          113345    ['quant_block3b_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block3c_expand_bn (Q  (None, 33, 33, 224)          899       ['quant_block3c_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block3c_expand_activ  (None, 33, 33, 224)          3         ['quant_block3c_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block3c_project_conv  (None, 33, 33, 56)           12657     ['quant_block3c_expand_activat
#   (QuantizeWrapperV2)                                               ion[0][0]']
#
#  quant_block3c_project_bn (  (None, 33, 33, 56)           227       ['quant_block3c_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block3c_drop (Quanti  (None, 33, 33, 56)           1         ['quant_block3c_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block3c_add (Quantiz  (None, 33, 33, 56)           3         ['quant_block3c_drop[0][0]',
#  eWrapperV2)                                                         'quant_block3b_add[0][0]']
#
#  quant_block4a_expand_conv   (None, 33, 33, 224)          12993     ['quant_block3c_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block4a_expand_bn (Q  (None, 33, 33, 224)          899       ['quant_block4a_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block4a_expand_activ  (None, 33, 33, 224)          3         ['quant_block4a_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block4a_dwconv2 (Qua  (None, 17, 17, 224)          2019      ['quant_block4a_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block4a_bn (Quantize  (None, 17, 17, 224)          899       ['quant_block4a_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block4a_activation (  (None, 17, 17, 224)          3         ['quant_block4a_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block4a_se_squeeze (  (None, 224)                  3         ['quant_block4a_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4a_se_reshape (  (None, 1, 1, 224)            1         ['quant_block4a_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4a_se_reduce (Q  (None, 1, 1, 14)             3181      ['quant_block4a_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block4a_se_expand (Q  (None, 1, 1, 224)            3811      ['quant_block4a_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block4a_se_excite (Multipl  (None, 17, 17, 224)          0         ['quant_block4a_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block4a_se_expand[0][0
#                                                                     ]']
#
#  quant_block4a_project_conv  (None, 17, 17, 104)          23505     ['block4a_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block4a_project_bn (  (None, 17, 17, 104)          419       ['quant_block4a_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block4b_expand_conv   (None, 17, 17, 416)          44097     ['quant_block4a_project_bn[0][
#  (QuantizeWrapperV2)                                                0]']
#
#  quant_block4b_expand_bn (Q  (None, 17, 17, 416)          1667      ['quant_block4b_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block4b_expand_activ  (None, 17, 17, 416)          3         ['quant_block4b_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block4b_dwconv2 (Qua  (None, 17, 17, 416)          3747      ['quant_block4b_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block4b_bn (Quantize  (None, 17, 17, 416)          1667      ['quant_block4b_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block4b_activation (  (None, 17, 17, 416)          3         ['quant_block4b_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block4b_se_squeeze (  (None, 416)                  3         ['quant_block4b_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4b_se_reshape (  (None, 1, 1, 416)            1         ['quant_block4b_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4b_se_reduce (Q  (None, 1, 1, 26)             10897     ['quant_block4b_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block4b_se_expand (Q  (None, 1, 1, 416)            12067     ['quant_block4b_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block4b_se_excite (Multipl  (None, 17, 17, 416)          0         ['quant_block4b_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block4b_se_expand[0][0
#                                                                     ]']
#
#  quant_block4b_project_conv  (None, 17, 17, 104)          43473     ['block4b_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block4b_project_bn (  (None, 17, 17, 104)          419       ['quant_block4b_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block4b_drop (Quanti  (None, 17, 17, 104)          1         ['quant_block4b_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block4b_add (Quantiz  (None, 17, 17, 104)          3         ['quant_block4b_drop[0][0]',
#  eWrapperV2)                                                         'quant_block4a_project_bn[0][
#                                                                     0]']
#
#  quant_block4c_expand_conv   (None, 17, 17, 416)          44097     ['quant_block4b_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block4c_expand_bn (Q  (None, 17, 17, 416)          1667      ['quant_block4c_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block4c_expand_activ  (None, 17, 17, 416)          3         ['quant_block4c_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block4c_dwconv2 (Qua  (None, 17, 17, 416)          3747      ['quant_block4c_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block4c_bn (Quantize  (None, 17, 17, 416)          1667      ['quant_block4c_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block4c_activation (  (None, 17, 17, 416)          3         ['quant_block4c_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block4c_se_squeeze (  (None, 416)                  3         ['quant_block4c_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4c_se_reshape (  (None, 1, 1, 416)            1         ['quant_block4c_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4c_se_reduce (Q  (None, 1, 1, 26)             10897     ['quant_block4c_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block4c_se_expand (Q  (None, 1, 1, 416)            12067     ['quant_block4c_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block4c_se_excite (Multipl  (None, 17, 17, 416)          0         ['quant_block4c_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block4c_se_expand[0][0
#                                                                     ]']
#
#  quant_block4c_project_conv  (None, 17, 17, 104)          43473     ['block4c_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block4c_project_bn (  (None, 17, 17, 104)          419       ['quant_block4c_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block4c_drop (Quanti  (None, 17, 17, 104)          1         ['quant_block4c_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block4c_add (Quantiz  (None, 17, 17, 104)          3         ['quant_block4c_drop[0][0]',
#  eWrapperV2)                                                         'quant_block4b_add[0][0]']
#
#  quant_block4d_expand_conv   (None, 17, 17, 416)          44097     ['quant_block4c_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block4d_expand_bn (Q  (None, 17, 17, 416)          1667      ['quant_block4d_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block4d_expand_activ  (None, 17, 17, 416)          3         ['quant_block4d_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block4d_dwconv2 (Qua  (None, 17, 17, 416)          3747      ['quant_block4d_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block4d_bn (Quantize  (None, 17, 17, 416)          1667      ['quant_block4d_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block4d_activation (  (None, 17, 17, 416)          3         ['quant_block4d_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block4d_se_squeeze (  (None, 416)                  3         ['quant_block4d_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4d_se_reshape (  (None, 1, 1, 416)            1         ['quant_block4d_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block4d_se_reduce (Q  (None, 1, 1, 26)             10897     ['quant_block4d_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block4d_se_expand (Q  (None, 1, 1, 416)            12067     ['quant_block4d_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block4d_se_excite (Multipl  (None, 17, 17, 416)          0         ['quant_block4d_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block4d_se_expand[0][0
#                                                                     ]']
#
#  quant_block4d_project_conv  (None, 17, 17, 104)          43473     ['block4d_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block4d_project_bn (  (None, 17, 17, 104)          419       ['quant_block4d_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block4d_drop (Quanti  (None, 17, 17, 104)          1         ['quant_block4d_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block4d_add (Quantiz  (None, 17, 17, 104)          3         ['quant_block4d_drop[0][0]',
#  eWrapperV2)                                                         'quant_block4c_add[0][0]']
#
#  quant_block5a_expand_conv   (None, 17, 17, 624)          66145     ['quant_block4d_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block5a_expand_bn (Q  (None, 17, 17, 624)          2499      ['quant_block5a_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block5a_expand_activ  (None, 17, 17, 624)          3         ['quant_block5a_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block5a_dwconv2 (Qua  (None, 17, 17, 624)          5619      ['quant_block5a_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block5a_bn (Quantize  (None, 17, 17, 624)          2499      ['quant_block5a_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block5a_activation (  (None, 17, 17, 624)          3         ['quant_block5a_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block5a_se_squeeze (  (None, 624)                  3         ['quant_block5a_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block5a_se_reshape (  (None, 1, 1, 624)            1         ['quant_block5a_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block5a_se_reduce (Q  (None, 1, 1, 26)             16305     ['quant_block5a_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block5a_se_expand (Q  (None, 1, 1, 624)            18099     ['quant_block5a_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block5a_se_excite (Multipl  (None, 17, 17, 624)          0         ['quant_block5a_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block5a_se_expand[0][0
#                                                                     ]']
#
#  quant_block5a_project_conv  (None, 17, 17, 120)          75121     ['block5a_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block5a_project_bn (  (None, 17, 17, 120)          483       ['quant_block5a_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block5b_expand_conv   (None, 17, 17, 720)          87841     ['quant_block5a_project_bn[0][
#  (QuantizeWrapperV2)                                                0]']
#
#  quant_block5b_expand_bn (Q  (None, 17, 17, 720)          2883      ['quant_block5b_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block5b_expand_activ  (None, 17, 17, 720)          3         ['quant_block5b_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block5b_dwconv2 (Qua  (None, 17, 17, 720)          6483      ['quant_block5b_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block5b_bn (Quantize  (None, 17, 17, 720)          2883      ['quant_block5b_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block5b_activation (  (None, 17, 17, 720)          3         ['quant_block5b_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block5b_se_squeeze (  (None, 720)                  3         ['quant_block5b_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block5b_se_reshape (  (None, 1, 1, 720)            1         ['quant_block5b_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block5b_se_reduce (Q  (None, 1, 1, 30)             21693     ['quant_block5b_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block5b_se_expand (Q  (None, 1, 1, 720)            23763     ['quant_block5b_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block5b_se_excite (Multipl  (None, 17, 17, 720)          0         ['quant_block5b_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block5b_se_expand[0][0
#                                                                     ]']
#
#  quant_block5b_project_conv  (None, 17, 17, 120)          86641     ['block5b_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block5b_project_bn (  (None, 17, 17, 120)          483       ['quant_block5b_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block5b_drop (Quanti  (None, 17, 17, 120)          1         ['quant_block5b_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block5b_add (Quantiz  (None, 17, 17, 120)          3         ['quant_block5b_drop[0][0]',
#  eWrapperV2)                                                         'quant_block5a_project_bn[0][
#                                                                     0]']
#
#  quant_block5c_expand_conv   (None, 17, 17, 720)          87841     ['quant_block5b_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block5c_expand_bn (Q  (None, 17, 17, 720)          2883      ['quant_block5c_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block5c_expand_activ  (None, 17, 17, 720)          3         ['quant_block5c_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block5c_dwconv2 (Qua  (None, 17, 17, 720)          6483      ['quant_block5c_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block5c_bn (Quantize  (None, 17, 17, 720)          2883      ['quant_block5c_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block5c_activation (  (None, 17, 17, 720)          3         ['quant_block5c_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block5c_se_squeeze (  (None, 720)                  3         ['quant_block5c_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block5c_se_reshape (  (None, 1, 1, 720)            1         ['quant_block5c_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block5c_se_reduce (Q  (None, 1, 1, 30)             21693     ['quant_block5c_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block5c_se_expand (Q  (None, 1, 1, 720)            23763     ['quant_block5c_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block5c_se_excite (Multipl  (None, 17, 17, 720)          0         ['quant_block5c_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block5c_se_expand[0][0
#                                                                     ]']
#
#  quant_block5c_project_conv  (None, 17, 17, 120)          86641     ['block5c_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block5c_project_bn (  (None, 17, 17, 120)          483       ['quant_block5c_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block5c_drop (Quanti  (None, 17, 17, 120)          1         ['quant_block5c_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block5c_add (Quantiz  (None, 17, 17, 120)          3         ['quant_block5c_drop[0][0]',
#  eWrapperV2)                                                         'quant_block5b_add[0][0]']
#
#  quant_block5d_expand_conv   (None, 17, 17, 720)          87841     ['quant_block5c_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block5d_expand_bn (Q  (None, 17, 17, 720)          2883      ['quant_block5d_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block5d_expand_activ  (None, 17, 17, 720)          3         ['quant_block5d_expand_bn[0][0
# ...
#  (QuantizeWrapperV2)
#
#  quant_block6h_expand_bn (Q  (None, 9, 9, 1248)           4995      ['quant_block6h_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block6h_expand_activ  (None, 9, 9, 1248)           3         ['quant_block6h_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block6h_dwconv2 (Qua  (None, 9, 9, 1248)           11235     ['quant_block6h_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block6h_bn (Quantize  (None, 9, 9, 1248)           4995      ['quant_block6h_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block6h_activation (  (None, 9, 9, 1248)           3         ['quant_block6h_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block6h_se_squeeze (  (None, 1248)                 3         ['quant_block6h_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block6h_se_reshape (  (None, 1, 1, 1248)           1         ['quant_block6h_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block6h_se_reduce (Q  (None, 1, 1, 52)             65055     ['quant_block6h_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block6h_se_expand (Q  (None, 1, 1, 1248)           68643     ['quant_block6h_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block6h_se_excite (Multipl  (None, 9, 9, 1248)           0         ['quant_block6h_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block6h_se_expand[0][0
#                                                                     ]']
#
#  quant_block6h_project_conv  (None, 9, 9, 208)            260001    ['block6h_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block6h_project_bn (  (None, 9, 9, 208)            835       ['quant_block6h_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block6h_drop (Quanti  (None, 9, 9, 208)            1         ['quant_block6h_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block6h_add (Quantiz  (None, 9, 9, 208)            3         ['quant_block6h_drop[0][0]',
#  eWrapperV2)                                                         'quant_block6g_add[0][0]']
#
#  quant_block6i_expand_conv   (None, 9, 9, 1248)           262081    ['quant_block6h_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block6i_expand_bn (Q  (None, 9, 9, 1248)           4995      ['quant_block6i_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block6i_expand_activ  (None, 9, 9, 1248)           3         ['quant_block6i_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block6i_dwconv2 (Qua  (None, 9, 9, 1248)           11235     ['quant_block6i_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block6i_bn (Quantize  (None, 9, 9, 1248)           4995      ['quant_block6i_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block6i_activation (  (None, 9, 9, 1248)           3         ['quant_block6i_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block6i_se_squeeze (  (None, 1248)                 3         ['quant_block6i_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block6i_se_reshape (  (None, 1, 1, 1248)           1         ['quant_block6i_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block6i_se_reduce (Q  (None, 1, 1, 52)             65055     ['quant_block6i_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block6i_se_expand (Q  (None, 1, 1, 1248)           68643     ['quant_block6i_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block6i_se_excite (Multipl  (None, 9, 9, 1248)           0         ['quant_block6i_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block6i_se_expand[0][0
#                                                                     ]']
#
#  quant_block6i_project_conv  (None, 9, 9, 208)            260001    ['block6i_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block6i_project_bn (  (None, 9, 9, 208)            835       ['quant_block6i_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block6i_drop (Quanti  (None, 9, 9, 208)            1         ['quant_block6i_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block6i_add (Quantiz  (None, 9, 9, 208)            3         ['quant_block6i_drop[0][0]',
#  eWrapperV2)                                                         'quant_block6h_add[0][0]']
#
#  quant_block6j_expand_conv   (None, 9, 9, 1248)           262081    ['quant_block6i_add[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_block6j_expand_bn (Q  (None, 9, 9, 1248)           4995      ['quant_block6j_expand_conv[0]
#  uantizeWrapperV2)                                                  [0]']
#
#  quant_block6j_expand_activ  (None, 9, 9, 1248)           3         ['quant_block6j_expand_bn[0][0
#  ation (QuantizeWrapperV2)                                          ]']
#
#  quant_block6j_dwconv2 (Qua  (None, 9, 9, 1248)           11235     ['quant_block6j_expand_activat
#  ntizeWrapperV2)                                                    ion[0][0]']
#
#  quant_block6j_bn (Quantize  (None, 9, 9, 1248)           4995      ['quant_block6j_dwconv2[0][0]'
#  WrapperV2)                                                         ]
#
#  quant_block6j_activation (  (None, 9, 9, 1248)           3         ['quant_block6j_bn[0][0]']
#  QuantizeWrapperV2)
#
#  quant_block6j_se_squeeze (  (None, 1248)                 3         ['quant_block6j_activation[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block6j_se_reshape (  (None, 1, 1, 1248)           1         ['quant_block6j_se_squeeze[0][
#  QuantizeWrapperV2)                                                 0]']
#
#  quant_block6j_se_reduce (Q  (None, 1, 1, 52)             65055     ['quant_block6j_se_reshape[0][
#  uantizeWrapperV2)                                                  0]']
#
#  quant_block6j_se_expand (Q  (None, 1, 1, 1248)           68643     ['quant_block6j_se_reduce[0][0
#  uantizeWrapperV2)                                                  ]']
#
#  block6j_se_excite (Multipl  (None, 9, 9, 1248)           0         ['quant_block6j_activation[0][
#  y)                                                                 0]',
#                                                                      'quant_block6j_se_expand[0][0
#                                                                     ]']
#
#  quant_block6j_project_conv  (None, 9, 9, 208)            260001    ['block6j_se_excite[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_block6j_project_bn (  (None, 9, 9, 208)            835       ['quant_block6j_project_conv[0
#  QuantizeWrapperV2)                                                 ][0]']
#
#  quant_block6j_drop (Quanti  (None, 9, 9, 208)            1         ['quant_block6j_project_bn[0][
#  zeWrapperV2)                                                       0]']
#
#  quant_block6j_add (Quantiz  (None, 9, 9, 208)            3         ['quant_block6j_drop[0][0]',
#  eWrapperV2)                                                         'quant_block6i_add[0][0]']
#
#  quant_top_conv (QuantizeWr  (None, 9, 9, 1408)           295681    ['quant_block6j_add[0][0]']
#  apperV2)
#
#  quant_top_bn (QuantizeWrap  (None, 9, 9, 1408)           5635      ['quant_top_conv[0][0]']
#  perV2)
#
#  quant_top_activation (Quan  (None, 9, 9, 1408)           3         ['quant_top_bn[0][0]']
#  tizeWrapperV2)
#
#  quant_avg_pool (QuantizeWr  (None, 1408)                 3         ['quant_top_activation[0][0]']
#  apperV2)
#
#  quant_top_dropout (Quantiz  (None, 1408)                 1         ['quant_avg_pool[0][0]']
#  eWrapperV2)
#
#  quant_dense (QuantizeWrapp  (None, 7)                    9868      ['quant_top_dropout[0][0]']
#  erV2)
#
# ==================================================================================================
# Total params: 8863851 (33.81 MB)
# Trainable params: 8696949 (33.18 MB)
# Non-trainable params: 166902 (651.96 KB)
# __________________________________________________________________________________________________

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(quant_aware_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

quantized_tflite_model = converter.convert()
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %%
quant_aware_model.save('/content/drive/MyDrive/ENV2B2quantized.h5')
# Out:
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Convert model to a quantized model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_model = quantized_tflite_model

# Load quantized model for fine-tuning
with tfmot.quantization.keras.quantize_scope():
    modelq = tf.keras.models.load_model('/content/drive/MyDrive/ENV2B2quantized.h5')

# Define custom loss function for quantization-aware training
def quantization_aware_loss(y_true, y_pred):
    # Define loss function here
    return tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)

# Define learning rate schedule for fine-tuning (dynamic learning rate)
def lr_schedule(epoch):
    lr = 1e-4
    if epoch >= 6:
        lr *= 0.1
    elif epoch >= 7:
        lr *= 0.01
    return lr

# Compile model for quantization-aware fine-tuning
modelq.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
class StopOnValidationAcc(Callback):
    def __init__(self, target_val_acc=0.98):
        super(StopOnValidationAcc, self).__init__()
        self.target_val_acc = target_val_acc

    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs.get('val_accuracy')
        if val_acc is not None and val_acc >= self.target_val_acc:
            print(f'\nReached {100 * self.target_val_acc}% validation accuracy, stopping training.')
            self.model.stop_training = True

stop_on_target_val_acc = StopOnValidationAcc(target_val_acc=0.98)

# %%
# Fine-tune model with a small learning rate
history = modelq.fit(train_generator,
                    steps_per_epoch=len(train_generator),
                    epochs=10,
                    validation_data=validation_generator,
                    validation_steps=len(validation_generator),
                    callbacks=[LearningRateScheduler(lr_schedule), stop_on_target_val_acc])

# # Save quantized model after fine-tuning
# modelq.save('/gdrive/MyDrive/quant_aware_modelB0fer.h5')
# Out:
# Epoch 1/10
# 43/43 [==============================] - 133s 1s/step - loss: 1.0326 - accuracy: 0.6818 - val_loss: 0.5931 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 2/10
# 43/43 [==============================] - 48s 1s/step - loss: 0.4764 - accuracy: 0.8328 - val_loss: 0.3832 - val_accuracy: 0.8503 - lr: 1.0000e-04
# Epoch 3/10
# 43/43 [==============================] - 50s 1s/step - loss: 0.3667 - accuracy: 0.8754 - val_loss: 0.2809 - val_accuracy: 0.8912 - lr: 1.0000e-04
# Epoch 4/10
# 43/43 [==============================] - 48s 1s/step - loss: 0.2352 - accuracy: 0.9208 - val_loss: 0.2121 - val_accuracy: 0.9116 - lr: 1.0000e-04
# Epoch 5/10
# 43/43 [==============================] - 48s 1s/step - loss: 0.1766 - accuracy: 0.9384 - val_loss: 0.1701 - val_accuracy: 0.9456 - lr: 1.0000e-04
# Epoch 6/10
# 43/43 [==============================] - 49s 1s/step - loss: 0.1593 - accuracy: 0.9501 - val_loss: 0.1288 - val_accuracy: 0.9524 - lr: 1.0000e-04
# Epoch 7/10
# 43/43 [==============================] - 60s 1s/step - loss: 0.1505 - accuracy: 0.9516 - val_loss: 0.1030 - val_accuracy: 0.9592 - lr: 1.0000e-05
# Epoch 8/10
# 43/43 [==============================] - 48s 1s/step - loss: 0.1307 - accuracy: 0.9589 - val_loss: 0.1044 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 9/10
# 43/43 [==============================] - 48s 1s/step - loss: 0.1080 - accuracy: 0.9692 - val_loss: 0.0802 - val_accuracy: 0.9660 - lr: 1.0000e-05
# Epoch 10/10
# 43/43 [==============================] - 48s 1s/step - loss: 0.1015 - accuracy: 0.9677 - val_loss: 0.0631 - val_accuracy: 0.9728 - lr: 1.0000e-05

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(modelq)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_tflite_model = converter.convert()
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %%
# Save the model to a file
with open('/content/drive/MyDrive/ENV2B2QAT.tflite', 'wb') as f:
  f.write(quantized_tflite_model)

# %% [markdown]
# ## **Post-training quantization (PTQ) - Quantization FP32 (float 32)**

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# %%
with open('/content/drive/MyDrive/ENV2B2PTQ.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ## **Prepare data**

# %%
test_datagen = ImageDataGenerator(preprocessing_function=lambda x: (x / 127.5) - 1.0)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(260, 260),
        batch_size=1,
        shuffle=False,
        class_mode='categorical')
# Out:
# Found 152 images belonging to 7 classes.

# %% [markdown]
# ## **Evaluation**

# %%
simple_model = os.path.getsize('/content/drive/MyDrive/ENV2B2CK+.h5')
qat = os.path.getsize('/content/drive/MyDrive/ENV2B2QAT.tflite')
ptq = os.path.getsize('/content/drive/MyDrive/ENV2B2PTQ.tflite')

print(f'Simple model size: {simple_model} bytes')
print(f'QAT model size: {qat} bytes')
print(f'PTQ model size: {ptq} bytes')
# Out:
# Simple model size: 106334120 bytes
# QAT model size: 22043144 bytes
# PTQ model size: 34722124 bytes

# %%
import time

def evaluate_tflite_model(model_path, test_generator, num_images):
    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    correct_count = 0
    total_count = 0
    total_time = 0.0

    for x, y_true in test_generator:
        if total_count >= num_images:
            break

        if x.shape != tuple(input_details[0]['shape']):
            x = np.reshape(x, input_details[0]['shape'])
        x = x.astype(input_details[0]['dtype'])
        interpreter.set_tensor(input_details[0]['index'], x)

        # Measure inference time
        start_time = time.time()
        interpreter.invoke()
        end_time = time.time()
        total_time += end_time - start_time

        y_pred = interpreter.get_tensor(output_details[0]['index'])
        y_pred = np.argmax(y_pred, axis=-1)
        y_true = np.argmax(y_true, axis=-1)
        correct_count += np.sum(y_pred == y_true)
        total_count += x.shape[0]

    accuracy = correct_count / total_count
    avg_inference_time = total_time / total_count
    return accuracy, avg_inference_time

# %%
evaluate_tflite_model('/content/drive/MyDrive/ENV2B2QAT.tflite', test_generator, 152)
# Out:
# (np.float64(0.9671052631578947), 0.052090080160843696)

# %%
evaluate_tflite_model('/content/drive/MyDrive/ENV2B2PTQ.tflite', test_generator, 152)
# Out:
# (np.float64(0.9736842105263158), 0.056357702142313906)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1" # Forces TF to use CPU

# %%
import time
import numpy as np

start_time = time.time()

# Assuming you have a trained model 'model' and a test data generator 'test_generator'
# Predict on the test data generator
predictions = model.predict(test_generator)

end_time = time.time()

# Calculate the total inference time
inference_time = end_time - start_time

# Calculate the average inference time per sample
num_samples = len(test_generator)
avg_inference_time_per_sample = inference_time / num_samples

print("Total inference time: {:.2f} seconds".format(inference_time))
print("Average inference time per image: {:.5f} seconds".format(avg_inference_time_per_sample))
# Out:
# 152/152 [==============================] - 2s 15ms/step
# Total inference time: 2.61 seconds
# Average inference time per image: 0.01718 seconds

# %%
import pandas as pd

# --- Model Sizes ---
simple_model_size = os.path.getsize('/content/drive/MyDrive/ENV2B2CK+.h5')
qat_model_size = os.path.getsize('/content/drive/MyDrive/ENV2B2QAT.tflite')
ptq_model_size = os.path.getsize('/content/drive/MyDrive/ENV2B2PTQ.tflite')

# --- Original Keras Model Metrics ---
# Accuracy was 0.9736841917037964 from model.evaluate(test_generator)
# Average inference time was 0.03332 seconds from cell wthzY6ShLLOA
keras_accuracy = 0.9736841917037964
keras_inference_time = 0.03332

# --- QAT TFLite Model Metrics ---
# From sEua0Lc7a1U_
qat_accuracy, qat_inference_time = evaluate_tflite_model('/content/drive/MyDrive/ENV2B2QAT.tflite', test_generator, 152)

# --- PTQ TFLite Model Metrics ---
# From LRApJo6Am-vi
ptq_accuracy, ptq_inference_time = evaluate_tflite_model('/content/drive/MyDrive/ENV2B2PTQ.tflite', test_generator, 152)

# Create a DataFrame for comparison
data = {
    'Model': ['Simple Keras', 'QAT TFLite', 'PTQ TFLite'],
    'Size (Bytes)': [simple_model_size, qat_model_size, ptq_model_size],
    'Accuracy': [keras_accuracy, qat_accuracy, ptq_accuracy],
    'Avg Inference Time (s/image)': [keras_inference_time, qat_inference_time, ptq_inference_time]
}

comparison_df = pd.DataFrame(data)

print(comparison_df.to_markdown(index=False))

# %%
import time
import numpy as np
import tensorflow as tf

def evaluate_tflite_model_fixed(model_path, test_generator, num_images):
    # FIX 1: Force TFLite to use multiple CPU cores (Colab usually has 2 to 4 cores)
    interpreter = tf.lite.Interpreter(model_path=model_path, num_threads=4)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # FIX 2: Warm-up run (Do not time the first inference, let the CPU cache the model)
    dummy_input = np.zeros(input_details[0]['shape'], dtype=input_details[0]['dtype'])
    interpreter.set_tensor(input_details[0]['index'], dummy_input)
    interpreter.invoke()

    correct_count = 0
    total_count = 0
    total_time = 0.0

    for x, y_true in test_generator:
        if total_count >= num_images:
            break

        if x.shape != tuple(input_details[0]['shape']):
            x = np.reshape(x, input_details[0]['shape'])
        x = x.astype(input_details[0]['dtype'])
        interpreter.set_tensor(input_details[0]['index'], x)

        start_time = time.time()
        interpreter.invoke()
        end_time = time.time()
        total_time += end_time - start_time

        y_pred = interpreter.get_tensor(output_details[0]['index'])
        y_pred = np.argmax(y_pred, axis=-1)
        y_true = np.argmax(y_true, axis=-1)
        correct_count += np.sum(y_pred == y_true)
        total_count += x.shape[0]

    accuracy = correct_count / total_count
    avg_inference_time = total_time / total_count
    return accuracy, avg_inference_time

# %%
evaluate_tflite_model('/content/drive/MyDrive/ENV2B2QAT.tflite', test_generator, 152)
# Out:
# (np.float64(0.9671052631578947), 0.09748311262381704)

# %%
evaluate_tflite_model('/content/drive/MyDrive/ENV2B2PTQ.tflite', test_generator, 152)
# Out:
# (np.float64(0.9736842105263158), 0.0632612124869698)

# %%
import time
import numpy as np

start_time = time.time()

# Assuming you have a trained model 'model' and a test data generator 'test_generator'
# Predict on the test data generator
predictions = model.predict(test_generator)

end_time = time.time()

# Calculate the total inference time
inference_time = end_time - start_time

# Calculate the average inference time per sample
num_samples = len(test_generator)
avg_inference_time_per_sample = inference_time / num_samples

print("Total inference time: {:.2f} seconds".format(inference_time))
print("Average inference time per image: {:.5f} seconds".format(avg_inference_time_per_sample))
# Out:
# 152/152 [==============================] - 3s 22ms/step
# Total inference time: 3.55 seconds
# Average inference time per image: 0.02334 seconds

# %%
import os
# RULE 1: Hide the GPU (Mobile phones do not have NVIDIA CUDA GPUs)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
import time
import numpy as np

# Reload the standard model so it binds to the CPU
standard_model = tf.keras.models.load_model('/content/drive/MyDrive/ENV2B2CK+.h5')

def benchmark_tflite_mobile_sim(model_path, test_gen, num_images):
    # RULE 2: Multi-Threading (Simulates a 4-core mobile CPU)
    interpreter = tf.lite.Interpreter(model_path=model_path, num_threads=4)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # RULE 3: Warm-UP (Simulates app launch / loading weights into CPU cache)
    dummy = np.zeros(input_details[0]['shape'], dtype=input_details[0]['dtype'])
    interpreter.set_tensor(input_details[0]['index'], dummy)
    interpreter.invoke()

    total_time = 0.0
    correct = 0

    for i, (x, y_true) in enumerate(test_gen):
        if i >= num_images: break

        x = x.astype(input_details[0]['dtype'])
        interpreter.set_tensor(input_details[0]['index'], x)

        # High-precision timer
        start = time.perf_counter()
        interpreter.invoke()
        end = time.perf_counter()
        total_time += (end - start)

        y_pred = interpreter.get_tensor(output_details[0]['index'])
        if np.argmax(y_pred) == np.argmax(y_true):
            correct += 1

    return correct/num_images, total_time/num_images

# Ensure generator is at the start
test_generator.reset()

print("⏳ Benchmarking QAT Model...")
qat_acc, qat_time = benchmark_tflite_mobile_sim('/content/drive/MyDrive/ENV2B2QAT.tflite', test_generator, 152)

test_generator.reset()
print("⏳ Benchmarking PTQ Model...")
ptq_acc, ptq_time = benchmark_tflite_mobile_sim('/content/drive/MyDrive/ENV2B2PTQ.tflite', test_generator, 152)

# Benchmark Standard Keras on CPU
test_generator.reset()
print("⏳ Benchmarking Standard Keras Model on CPU...")
# Warmup for Keras
_ = standard_model.predict(test_generator, steps=10, verbose=0)
test_generator.reset()

start = time.perf_counter()
_ = standard_model.predict(test_generator, steps=152, verbose=0)
end = time.perf_counter()
std_time = (end - start) / 152

print("\n" + "="*45)
print("📱 MOBILE-SIMULATED BENCHMARK RESULTS")
print("="*45)
print(f"✅ QAT Model (INT8):  {qat_acc*100:.2f}% Acc | {qat_time*1000:.2f} ms/image")
print(f"✅ PTQ Model (INT8):  {ptq_acc*100:.2f}% Acc | {ptq_time*1000:.2f} ms/image")
print(f"⚪ Standard (FP32):   {std_time*1000:.2f} ms/image (CPU)")
print("="*45)
# Out:
# ⏳ Benchmarking QAT Model...
# ⏳ Benchmarking PTQ Model...
# ⏳ Benchmarking Standard Keras Model on CPU...
#
# =============================================
# 📱 MOBILE-SIMULATED BENCHMARK RESULTS
# =============================================
# ✅ QAT Model (INT8):  96.71% Acc | 87.84 ms/image
# ✅ PTQ Model (INT8):  97.37% Acc | 89.47 ms/image
# ⚪ Standard (FP32):   14.92 ms/image (CPU)
# =============================================
